# %% [markdown]
# #Chapter 1 Exercises
#
# Problems 1, 3, 5

# %% [markdown]
# ##Exercise 1
#
# Working with the print statement to print to screen.

# %%
print('This is a test of the Python interpreter.')
# Out:
# This is a test of the Python interpreter.

# %%
print('This is a Hello World!')
# Out:
# This is a Hello World!

# %%
print('Three dogs named Peaches, Piper, and Buddy like two tiny kittens named Finn and Freya.')
# Out:
# Three dogs named Peaches, Piper, and Buddy like two tiny kittens named Finn and Freya.

# %% [markdown]
# ##Exercise 3
#
# Convert decimal to binary.

# %% [markdown]
# 128 | 64 | 32 | 16 | 8 | 4 | 2 | 1 = Binary digits
#
# 11 decimal to binary = 1011
# 65 decimal to binary = 1000001
# 100 decimal to binary = 1100100
# 255 decimal to binary = 11111111

# %% [markdown]
# ##Exercise 5
#
# Convert first name to ASCII

# %% [markdown]
# Start with converting each individual letter.
#
# C = 67
# a = 97
# s = 115
# e = 101
# y = 121

# %% [markdown]
# Formatted in Tab Delimited Format
# 67  97  115 101 121

# %% [markdown]
# Formatted with semicolon delimiter
# 67;97;115;101;121
